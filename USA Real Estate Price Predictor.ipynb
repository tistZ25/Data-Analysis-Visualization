# %%
import pandas as pd
import numpy as np
data = pd.read_csv(r"C:\Users\acer\Desktop\real-estate\realtor-data.csv")

# %%
data
# Out:
#          brokered_by    status     price  bed  bath  acre_lot     street  \
# 0           103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1            52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2           103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3            31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4            34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
# ...              ...       ...       ...  ...   ...       ...        ...
# 2226377      23009.0      sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0      sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0      sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0      sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0      sold  580000.0  5.0   3.0      0.31   307704.0
#
#                city        state  zip_code  house_size prev_sold_date
# ...

# %%
data.head(10)
# Out:
#    brokered_by    status     price  bed  bath  acre_lot     street  \
# 0     103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1      52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2     103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3      31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4      34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
# 5     103378.0  for_sale  179000.0  4.0   3.0      0.46  1850806.0
# 6       1205.0  for_sale   50000.0  3.0   1.0      0.20  1298094.0
# 7      50739.0  for_sale   71600.0  3.0   2.0      0.08  1048466.0
# 8      81909.0  for_sale  100000.0  2.0   1.0      0.09   734904.0
# 9      65672.0  for_sale  300000.0  5.0   3.0      7.46  1946226.0
#
#             city        state  zip_code  house_size prev_sold_date
# 0       Adjuntas  Puerto Rico     601.0       920.0            NaN
# 1       Adjuntas  Puerto Rico     601.0      1527.0            NaN
# ...

# %%
data.tail()
# Out:
#          brokered_by status     price  bed  bath  acre_lot     street  \
# 2226377      23009.0   sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0   sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0   sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0   sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0   sold  580000.0  5.0   3.0      0.31   307704.0
#
#              city       state  zip_code  house_size prev_sold_date
# 2226377  Richland  Washington   99354.0      3600.0     2022-03-25
# 2226378  Richland  Washington   99354.0      1616.0     2022-03-25
# 2226379  Richland  Washington   99354.0      3200.0     2022-03-24
# 2226380  Richland  Washington   99354.0       933.0     2022-03-24
# 2226381  Richland  Washington   99354.0      3615.0     2022-03-23

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          object
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            object
#  8   state           object
#  9   zip_code        float64
#  10  house_size      float64
#  11  prev_sold_date  object
# dtypes: float64(8), object(4)
# memory usage: 203.8+ MB

# %%
data.describe()
# Out:
#         brokered_by         price           bed          bath      acre_lot  \
# count  2.221849e+06  2.224841e+06  1.745065e+06  1.714611e+06  1.900793e+06
# mean   5.293989e+04  5.241955e+05  3.275841e+00  2.496440e+00  1.522303e+01
# std    3.064275e+04  2.138893e+06  1.567274e+00  1.652573e+00  7.628238e+02
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.386100e+04  1.650000e+05  3.000000e+00  2.000000e+00  1.500000e-01
# 50%    5.288400e+04  3.250000e+05  3.000000e+00  2.000000e+00  2.600000e-01
# 75%    7.918300e+04  5.500000e+05  4.000000e+00  3.000000e+00  9.800000e-01
# max    1.101420e+05  2.147484e+09  4.730000e+02  8.300000e+02  1.000000e+05
#
#              street      zip_code    house_size
# count  2.215516e+06  2.226083e+06  1.657898e+06
# mean   1.012325e+06  5.218668e+04  2.714471e+03
# std    5.837635e+05  2.895408e+04  8.081635e+05
# min    0.000000e+00  0.000000e+00  4.000000e+00
# ...

# %%
data.isna().sum()
# Out:
# brokered_by         4533
# status                 0
# price               1541
# bed               481317
# bath              511771
# acre_lot          325589
# street             10866
# city                1407
# state                  8
# zip_code             299
# house_size        568484
# prev_sold_date    734297
# dtype: int64

# %%
data.drop(columns = ["brokered_by", "zip_code", "prev_sold_date"], inplace = True)

# %%
data
# Out:
#            status     price  bed  bath  acre_lot     street        city  \
# 0        for_sale  105000.0  3.0   2.0      0.12  1962661.0    Adjuntas
# 1        for_sale   80000.0  4.0   2.0      0.08  1902874.0    Adjuntas
# 2        for_sale   67000.0  2.0   1.0      0.15  1404990.0  Juana Diaz
# 3        for_sale  145000.0  4.0   2.0      0.10  1947675.0       Ponce
# 4        for_sale   65000.0  6.0   2.0      0.05   331151.0    Mayaguez
# ...           ...       ...  ...   ...       ...        ...         ...
# 2226377      sold  359900.0  4.0   2.0      0.33   353094.0    Richland
# 2226378      sold  350000.0  3.0   2.0      0.10  1062149.0    Richland
# 2226379      sold  440000.0  6.0   3.0      0.50   405677.0    Richland
# 2226380      sold  179900.0  2.0   1.0      0.09   761379.0    Richland
# 2226381      sold  580000.0  5.0   3.0      0.31   307704.0    Richland
#
#                state  house_size
# 0        Puerto Rico       920.0
# 1        Puerto Rico      1527.0
# ...

# %%
data.isna().sum().sum()
# Out:
# 1900983

# %%
data.shape
# Out:
# (2226382, 9)

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#            status     price  bed  bath  acre_lot     street           city  \
# 0        for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1        for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2        for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3        for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5        for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
# ...           ...       ...  ...   ...       ...        ...            ...
# 2226377      sold  359900.0  4.0   2.0      0.33   353094.0       Richland
# 2226378      sold  350000.0  3.0   2.0      0.10  1062149.0       Richland
# 2226379      sold  440000.0  6.0   3.0      0.50   405677.0       Richland
# 2226380      sold  179900.0  2.0   1.0      0.09   761379.0       Richland
# 2226381      sold  580000.0  5.0   3.0      0.31   307704.0       Richland
#
#                state  house_size
# 0        Puerto Rico       920.0
# ...

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data.head()
# Out:
#      status     price  bed  bath  acre_lot     street           city  \
# 0  for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1  for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2  for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3  for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5  for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
#
#          state  house_size
# 0  Puerto Rico       920.0
# 1  Puerto Rico      1527.0
# 2  Puerto Rico       748.0
# 3  Puerto Rico      1800.0
# 5  Puerto Rico      2520.0

# %%
data.duplicated().sum()
# Out:
# 535

# %%
data.drop_duplicates(inplace = True)

# %%
data.head()
# Out:
#      status     price  bed  bath  acre_lot     street           city  \
# 0  for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1  for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2  for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3  for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5  for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
#
#          state  house_size
# 0  Puerto Rico       920.0
# 1  Puerto Rico      1527.0
# 2  Puerto Rico       748.0
# 3  Puerto Rico      1800.0
# 5  Puerto Rico      2520.0

# %%
data["status"].value_counts()
# Out:
# status
# for_sale    747459
# sold        608403
# Name: count, dtype: int64

# %%
data["state"].value_counts().sort_values(ascending = True).head()
# Out:
# state
# Guam               116
# Virgin Islands     122
# Alaska             810
# Vermont           1262
# New Hampshire     1734
# Name: count, dtype: int64

# %%
data["state"].value_counts().sort_values(ascending = True).head()
# Out:
# state
# Guam               116
# Virgin Islands     122
# Alaska             810
# Vermont           1262
# New Hampshire     1734
# Name: count, dtype: int64

# %%
data["state"].value_counts().head()
# Out:
# state
# California      170550
# Texas           145188
# Florida         126328
# Arizona          54475
# Pennsylvania     51847
# Name: count, dtype: int64

# %%
data["state"].value_counts().sort_values(ascending = False).head(10)
# Out:
# state
# California      170550
# Texas           145188
# Florida         126328
# Arizona          54475
# Pennsylvania     51847
# New York         50697
# Georgia          49134
# Illinois         46640
# Washington       46336
# Virginia         44159
# Name: count, dtype: int64

# %%
data["state"].value_counts().sort_values(ascending = False).head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='state'>

# %%
import matplotlib.pyplot as plt

# %%
data["state"].value_counts().sort_values(ascending = False).head(10).plot(kind = 'bar')
plt.title("House Counts by States")
plt.ylabel("Count of Houses")
plt.xlabel("State")
plt.show()

# %%
data.groupby("state")["price"].mean().sort_values(ascending = False).astype(int)
# Out:
# state
# Virgin Islands          1947522
# Hawaii                  1491548
# District of Columbia    1209649
# California              1107572
# Colorado                 952486
# Utah                     914531
# Montana                  862815
# Connecticut              790488
# Massachusetts            754230
# Nevada                   751439
# Washington               727478
# Wyoming                  719581
# Guam                     717504
# Idaho                    689815
# New York                 657557
# Florida                  649977
# Oregon                   645160
# New Hampshire            640991
# Puerto Rico              632210
# Vermont                  557932
# Arizona                  552891
# Virginia                 546274
# Alaska                   541288
# New Jersey               541131
# Maine                    517891
# Rhode Island             511094
# Maryland                 502889
# South Carolina           485025
# Tennessee                485018
# ...

# %%
data.groupby("city")["price"].mean().sort_values(ascending = False).astype(int)
# Out:
# city
# International      2147483600
# Bolingbroke          45250000
# Bal Harbour          26585714
# Gulf Stream          21461250
# Woody Creek          20987500
#                       ...
# Otter Rock              10033
# Midwest                 10000
# Center Junction          8500
# Rowan                    7500
# Pilot Mound              6500
# Name: price, Length: 17114, dtype: int32

# %%
# Multi-Index Groupby
data.groupby(["state","city"])["price"].mean().astype(int)
# Out:
# state    city
# Alabama  Abbeville      220154
#          Adamsville     138441
#          Addison        145950
#          Adger          174372
#          Akron          438940
#                         ...
# Wyoming  Wheatland      281578
#          Wilson        5719900
#          Worland        288907
#          Wright         291160
#          Yoder          340666
# Name: price, Length: 26260, dtype: int32

# %%
# To get as Pandas DataFrame
data.groupby(["state","city"])["price"].mean().astype(int).reset_index()
# Out:
#          state        city    price
# 0      Alabama   Abbeville   220154
# 1      Alabama  Adamsville   138441
# 2      Alabama     Addison   145950
# 3      Alabama       Adger   174372
# 4      Alabama       Akron   438940
# ...        ...         ...      ...
# 26255  Wyoming   Wheatland   281578
# 26256  Wyoming      Wilson  5719900
# 26257  Wyoming     Worland   288907
# 26258  Wyoming      Wright   291160
# 26259  Wyoming       Yoder   340666
#
# [26260 rows x 3 columns]

# %%
data
# Out:
#            status     price  bed  bath  acre_lot     street           city  \
# 0        for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1        for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2        for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3        for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5        for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
# ...           ...       ...  ...   ...       ...        ...            ...
# 2226377      sold  359900.0  4.0   2.0      0.33   353094.0       Richland
# 2226378      sold  350000.0  3.0   2.0      0.10  1062149.0       Richland
# 2226379      sold  440000.0  6.0   3.0      0.50   405677.0       Richland
# 2226380      sold  179900.0  2.0   1.0      0.09   761379.0       Richland
# 2226381      sold  580000.0  5.0   3.0      0.31   307704.0       Richland
#
#                state  house_size
# 0        Puerto Rico       920.0
# ...

# %%
data.select_dtypes(include = ["number"]).corr()["price"]
# Out:
# price         1.000000
# bed           0.117585
# bath          0.208868
# acre_lot      0.005304
# street        0.000481
# house_size    0.073849
# Name: price, dtype: float64

# %%
# acre_lot and street has about 0 correlation with price (not signifaicant)
x = data[["bed", "bath", "house_size"]]

# %%
y = data["price"]

# %%
x
# Out:
#          bed  bath  house_size
# 0        3.0   2.0       920.0
# 1        4.0   2.0      1527.0
# 2        2.0   1.0       748.0
# 3        4.0   2.0      1800.0
# 5        4.0   3.0      2520.0
# ...      ...   ...         ...
# 2226377  4.0   2.0      3600.0
# 2226378  3.0   2.0      1616.0
# 2226379  6.0   3.0      3200.0
# 2226380  2.0   1.0       933.0
# 2226381  5.0   3.0      3615.0
#
# [1355862 rows x 3 columns]

# %%
y
# Out:
# 0          105000.0
# 1           80000.0
# 2           67000.0
# 3          145000.0
# 5          179000.0
#              ...
# 2226377    359900.0
# 2226378    350000.0
# 2226379    440000.0
# 2226380    179900.0
# 2226381    580000.0
# Name: price, Length: 1355862, dtype: float64

# %%
# To Train a Linear Regression Model
# Scale the data

# %%
x.columns
# Out:
# Index(['bed', 'bath', 'house_size'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
# We evaluate our model with the testing set and train our model with the training set. 
# Here 20% of the data is at test set and 80% of the data in the training set

# %%
len(y_train)
# Out:
# 1084689

# %%
len(y_test)
# Out:
# 271173

# %%
# Scaling x features
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train
# Out:
#          bed  bath  house_size
# 965309   3.0   2.0      1891.0
# 318614   3.0   3.0      1572.0
# 1430954  4.0   4.0      3755.0
# 1970057  3.0   4.0      2732.0
# 1522949  4.0   2.0      2128.0
# ...      ...   ...         ...
# 1063589  4.0   4.0      4349.0
# 1552999  4.0   2.0      1472.0
# 515636   3.0   2.0      1532.0
# 257      3.0   3.0      2400.0
# 1463058  3.0   2.0      2840.0
#
# [1084689 rows x 3 columns]

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.2771617 , -0.40243223, -0.05278232],
#        [-0.2771617 ,  0.34106609, -0.1257833 ],
#        [ 0.44252902,  1.08456442,  0.37378141],
#        ...,
#        [-0.2771617 , -0.40243223, -0.13493703],
#        [-0.2771617 ,  0.34106609,  0.06369887],
#        [-0.2771617 , -0.40243223,  0.16438988]])

# %%
import joblib
joblib.dump(scaler, "Scaler.pkl")
# Out:
# ['Scaler.pkl']

# %%
x_test = scaler.fit_transform(x_test)

# %%
# Training
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(x_test)

# %%
predictions
# Out:
# array([ 144921.03015463,  334342.58037655, 1130745.11320942, ...,
#         395276.95409904,  329432.39049819,   13196.19248109])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 346092.4402949116

# %%
data["price"].describe().astype(int)
# Out:
# count       1355862
# mean         574225
# std         2212087
# min               0
# 25%          239000
# 50%          379000
# 75%          600000
# max      2147483600
# Name: price, dtype: int32

# %%
joblib.dump(lr, "model.pkl")
# Out:
# ['model.pkl']
